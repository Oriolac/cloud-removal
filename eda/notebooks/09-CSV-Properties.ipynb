# %%
import pandas as pd

# %%
dfs = [pd.read_pickle(f'..\output\ROIs1158_spring_6_{_type}.pkl') for _type in ['cloudless', 'cloudy', 'paired']]

# %%
dfs[1].cloud_percentage
# Out:
# 0      0.995377
# 1      0.912693
# 2      0.998991
# 3      0.998741
# 4      0.998910
#          ...
# 695    0.997258
# 696    0.998551
# 697    0.947623
# 698    0.999522
# 699    0.996386
# Name: cloud_percentage, Length: 700, dtype: float32

# %%
for col in dfs[0].columns:
    print(col)
# Out:
# 0_traditional_contrast
# 0_michelson_contrast
# 0_rms_contrast
# 0_laplacian_blur
# 0_mean
# 0_median
# 0_p25
# 0_p75
# 0_std
# 1_traditional_contrast
# 1_michelson_contrast
# 1_rms_contrast
# 1_laplacian_blur
# 1_mean
# 1_median
# 1_p25
# 1_p75
# 1_std
# 2_traditional_contrast
# 2_michelson_contrast
# 2_rms_contrast
# 2_laplacian_blur
# 2_mean
# 2_median
# 2_p25
# 2_p75
# 2_std
# 3_traditional_contrast
# 3_michelson_contrast
# 3_rms_contrast
# 3_laplacian_blur
# 3_mean
# 3_median
# 3_p25
# 3_p75
# 3_std
# 4_traditional_contrast
# 4_michelson_contrast
# 4_rms_contrast
# 4_laplacian_blur
# 4_mean
# 4_median
# 4_p25
# 4_p75
# 4_std
# 5_traditional_contrast
# 5_michelson_contrast
# 5_rms_contrast
# 5_laplacian_blur
# 5_mean
# 5_median
# 5_p25
# 5_p75
# 5_std
# 6_traditional_contrast
# 6_michelson_contrast
# 6_rms_contrast
# 6_laplacian_blur
# 6_mean
# 6_median
# 6_p25
# 6_p75
# 6_std
# 7_traditional_contrast
# 7_michelson_contrast
# 7_rms_contrast
# 7_laplacian_blur
# 7_mean
# 7_median
# ...

# %%
for col in dfs[1].columns:
    print(col)
# Out:
# 0_traditional_contrast
# 0_michelson_contrast
# 0_rms_contrast
# 0_laplacian_blur
# 0_mean
# 0_median
# 0_p25
# 0_p75
# 0_std
# 1_traditional_contrast
# 1_michelson_contrast
# 1_rms_contrast
# 1_laplacian_blur
# 1_mean
# 1_median
# 1_p25
# 1_p75
# 1_std
# 2_traditional_contrast
# 2_michelson_contrast
# 2_rms_contrast
# 2_laplacian_blur
# 2_mean
# 2_median
# 2_p25
# 2_p75
# 2_std
# 3_traditional_contrast
# 3_michelson_contrast
# 3_rms_contrast
# 3_laplacian_blur
# 3_mean
# 3_median
# 3_p25
# 3_p75
# 3_std
# 4_traditional_contrast
# 4_michelson_contrast
# 4_rms_contrast
# 4_laplacian_blur
# 4_mean
# 4_median
# 4_p25
# 4_p75
# 4_std
# 5_traditional_contrast
# 5_michelson_contrast
# 5_rms_contrast
# 5_laplacian_blur
# 5_mean
# 5_median
# 5_p25
# 5_p75
# 5_std
# 6_traditional_contrast
# 6_michelson_contrast
# 6_rms_contrast
# 6_laplacian_blur
# 6_mean
# 6_median
# 6_p25
# 6_p75
# 6_std
# 7_traditional_contrast
# 7_michelson_contrast
# 7_rms_contrast
# 7_laplacian_blur
# 7_mean
# 7_median
# ...

# %%
for col in dfs[2].columns:
    print(col)
# Out:
# b0_mse_paired
# b1_mse_paired
# b2_mse_paired
# b3_mse_paired
# b4_mse_paired
# b5_mse_paired
# b6_mse_paired
# b7_mse_paired
# b8_mse_paired
# b9_mse_paired
# b10_mse_paired
# b11_mse_paired
# b12_mse_paired
